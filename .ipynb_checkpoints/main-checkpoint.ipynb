# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Note:加速度的单位是g(重力加速度),角速度单位是角度制

# %%
raw_data=pd.read_csv('meta_data/Data1.csv')
label_1=pd.read_csv('meta_data/Label_of_Data1.csv')

# %%
raw_data['label']=0

for k in range(len(label_1)):
    if label_1.iloc[k,0]=='-1' or '-2':
       raw_data.iloc[label_1.iloc[k,1]:label_1.iloc[k,2]+1,-1]=label_1.iloc[k,0]

# %%
index_guodu=np.where(raw_data['label']=='-1',True,False)
index_start=np.where(raw_data['label']=='-2',True,False)
raw_data['label']=0
data_p=np.array(raw_data)
data_p[index_guodu,-1]
#data_p[index_start,-1]

#data_p.astype('float64')
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
sns.set()
plt.plot(data_p[index_guodu][0],data_p[index_guodu][1])
data_p[index_guodu][0].shape
# Out:
# (8,)
